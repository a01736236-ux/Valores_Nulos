# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Convertimos el dataset en dataframe
df= pd.read_csv("Oporto_Portugal.csv")
df
# Out:
#        Unnamed: 0                   id  \
# 0               0                41339
# 1               1                55111
# 2               2                73828
# 3               3                87873
# 4               4                94701
# ...           ...                  ...
# 14868       14868  1442944169953064519
# 14869       14869  1442949312063381006
# 14870       14870  1442972095274896534
# 14871       14871  1443457123327763296
# 14872       14872  1443457546151071185
#
#                                             listing_url last_scraped  \
# 0                    https://www.airbnb.com/rooms/41339   2025-06-28
# 1                    https://www.airbnb.com/rooms/55111   2025-06-26
# 2                    https://www.airbnb.com/rooms/73828   2025-06-26
# 3                    https://www.airbnb.com/rooms/87873   2025-06-26
# 4                    https://www.airbnb.com/rooms/94701   2025-06-27
# ...                                                 ...          ...
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                          0
# id                                  0
# listing_url                         0
# last_scraped                        0
# source                              0
# name                                0
# description                       348
# neighborhood_overview            6531
# picture_url                         0
# host_id                             0
# host_url                            0
# host_name                           0
# host_since                          0
# host_location                    5011
# host_about                       7056
# host_response_time               2233
# host_response_rate               2233
# host_acceptance_rate             1695
# host_is_superhost                 848
# host_thumbnail_url                  0
# host_picture_url                    0
# host_neighbourhood              13745
# host_listings_count                 0
# host_total_listings_count           0
# host_verifications                  0
# ...

# %%
df["calendar_updated"] =df["calendar_updated"].fillna("calendar_updated")

# %%
df["has_availability"] =df["has_availability"].fillna("has_availability")

# %%
df["neighborhood_overview"] =df["neighborhood_overview"].fillna("neighborhood_overview")

# %%
df["host_neighbourhood"] =df["host_neighbourhood"].fillna("host_neighbourhood")

# %%
df["host_about"] =df["host_about"].fillna("host_about")

# %%
df["host_location"] =df["host_location"].fillna("host_location")

# %%
df["host_response_time"] =df["host_response_time"].fillna("host_response_time")

# %%
df["host_response_rate"] =df["host_response_rate"].fillna("host_response_rate")

# %%
df["host_acceptance_rate"] =df["host_acceptance_rate"].fillna("host_acceptance_rate")

# %%
df["host_is_superhost"] =df["host_is_superhost"].fillna("host_is_superhost")

# %%
df["description"] =df["description"].fillna("description")

# %%
#Identificar valores nulos por columna
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                         0
# id                                 0
# listing_url                        0
# last_scraped                       0
# source                             0
# name                               0
# description                        0
# neighborhood_overview              0
# picture_url                        0
# host_id                            0
# host_url                           0
# host_name                          0
# host_since                         0
# host_location                      0
# host_about                         0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate               0
# host_is_superhost                  0
# host_thumbnail_url                 0
# host_picture_url                   0
# host_neighbourhood                 0
# host_listings_count                0
# host_total_listings_count          0
# host_verifications                 0
# ...

# %%
df.to_csv('Oporto_Portugal_Actualizado.csv', index=False)
